# %% [markdown]
# <a href="https://colab.research.google.com/github/tirtasm/DataCleaning/blob/main/DataCleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/csv/Customer Call List.xlsx')
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
# df = df.drop(['CustomerID'], axis=1)
# df


df.drop(columns="CustomerID")
# Out:
#    First_Name    Last_Name  Phone_Number  \
# 0       Frodo      Baggins  123-545-5421
# 1        Abed        Nadir  123/643/9775
# 2      Walter       /White    7066950392
# 3      Dwight      Schrute  123-543-2345
# 4         Jon         Snow  876|678|3469
# 5         Ron      Swanson  304-762-2467
# 6        Jeff       Winger           NaN
# 7    Sherlock       Holmes  876|678|3469
# 8     Gandalf          NaN           N/a
# 9       Peter       Parker  123-545-5421
# 10    Samwise       Gamgee           NaN
# 11      Harry    ...Potter    7066950392
# 12        Don       Draper  123-543-2345
# 13     Leslie        Knope  876|678|3469
# 14       Toby  Flenderson_  304-762-2467
# 15        Ron      Weasley  123-545-5421
# 16   Michael         Scott  123/643/9775
# 17      Clark         Kent    7066950392
# 18      Creed       Braton           N/a
# 19     Anakin    Skywalker  876|678|3469
# 20     Anakin    Skywalker  876|678|3469
#
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
# df["Last_Name"] = df['Last_Name'].str.lstrip("...")
# df["Last_Name"] = df['Last_Name'].str.lstrip("/")
# df["Last_Name"] = df['Last_Name'].str.rstrip("_")
df["Last_Name"] = df['Last_Name'].str.strip("./_")

df
# Out:
# <ipython-input-7-9b9a11dd575d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Last_Name"] = df['Last_Name'].str.strip("./_")
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# ...

# %%
#hapus nan
# df['Phone_Number'] = df["Phone_Number"].str.replace('Na',' ')
df = df.fillna('')

df['Phone_Number']
# Out:
# 0     1235455421
# 1     1236439775
# 2
# 3     1235432345
# 4     8766783469
# 5     3047622467
# 6
# 7     8766783469
# 8
# 9     1235455421
# 10
# 11
# 12    1235432345
# 13    8766783469
# 14    3047622467
# 15    1235455421
# 16    1236439775
# 17
# 18
# 19    8766783469
# Name: Phone_Number, dtype: object

# %%
df["Phone_Number"]=df["Phone_Number"].str.replace('[^a-zA-Z0-9]','')
# Out:
# <ipython-input-12-eac0e7445766>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["Phone_Number"]=df["Phone_Number"].str.replace('[^a-zA-Z0-9]','')
# <ipython-input-12-eac0e7445766>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Phone_Number"]=df["Phone_Number"].str.replace('[^a-zA-Z0-9]','')
